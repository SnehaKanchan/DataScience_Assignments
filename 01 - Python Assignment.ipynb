# %% [markdown]
# # Q7. Calculate Mean, Median, Mode, Variance, Standard Deviation, Range & comment about the values / draw inferences, for the given dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-8fc2f5a6-27ca-4910-9c90-bf1e8b52b267" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fc2f5a6-27ca-4910-9c90-bf1e8b52b267">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cars = pd.read_csv("Cars.csv")
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
cars.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %%
cars.HP.mode()
# Out:
# 0    92
# Name: HP, dtype: int64

# %%
cars.MPG.mode()
# Out:
# 0    29.629936
# Name: MPG, dtype: float64

# %%
cars.VOL.mode()
# Out:
# 0    50
# Name: VOL, dtype: int64

# %%
cars.SP.mode()
# Out:
# 0    118.288996
# Name: SP, dtype: float64

# %%
cars.WT.mode()
# Out:
# 0     15.712859
# 1     15.753535
# 2     15.769625
# 3     15.823060
# 4     15.847758
#         ...
# 76    42.778219
# 77    43.353123
# 78    43.390988
# 79    44.013139
# 80    52.997752
# Name: WT, Length: 81, dtype: float64

# %%
cars.var()
# Out:
# HP     3261.952160
# MPG      83.383283
# VOL     497.356790
# SP      201.113002
# WT       56.142247
# dtype: float64

# %%
cars.std()
# Out:
# HP     57.113502
# MPG     9.131445
# VOL    22.301497
# SP     14.181432
# WT      7.492813
# dtype: float64

# %%
# Range

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
HP_Range = cars.HP.max() - cars.HP.min()
HP_Range
# Out:
# 273

# %%
MPG_Range = cars.MPG.max() - cars.MPG.min()
MPG_Range
# Out:
# 41.59941849

# %%
WT_Range = cars.WT.max() - cars.WT.min()
WT_Range
# Out:
# 37.28489383

# %%
ax = plt.subplots(figsize=(15,5))
plt.subplot(1,3,1)
plt.boxplot(cars.HP)
plt.title('HP')
plt.subplot(1,3,2)
plt.boxplot(cars.MPG)
plt.title('MPG')
plt.subplot(1,3,3)
plt.boxplot(cars.WT)
plt.title('WT')
plt.show()
# Out:
# <ipython-input-21-0f4aa5839973>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)

# %% [markdown]
# # 8) Calculate Expected Value for the problem below
# 	a)	The weights (X) of patients at a clinic (in pounds), are
# 108, 110, 123, 134, 135, 145, 167, 187, 199
# Assume one of the patients is chosen at random. What is the Expected Value of the Weight of that patient?

# %%
import numpy as np
patient = np.array([108,110, 123, 134, 135, 145, 167, 187, 199])

# %%
patient.mean()
# Out:
# 145.33333333333334

# %% [markdown]
# #9) Calculate Skewness, Kurtosis & draw inferences on the following data

# %%
import numpy as np
import pandas as pd
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-2cc164e2-8355-4009-9a1c-813dca95bd75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2cc164e2-8355-4009-9a1c-813dca95bd75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("Q9_a.csv")
data
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
data.skew(axis=0, skipna = True)
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   50 non-null     int64
#  1   speed   50 non-null     int64
#  2   dist    50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB

# %% [markdown]
# #Q11)  Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import norm

# %%
stats.norm.interval(0.94, 200,30/(2000**0.5))
# Out:
# (198.738325292158, 201.261674707842)

# %%
stats.norm.interval(0.98, 200,30/(2000**0.5))
# Out:
# (198.43943840429978, 201.56056159570022)

# %%
stats.norm.interval(0.96, 200,30/(2000**0.5))
# Out:
# (198.62230334813333, 201.37769665186667)

# %% [markdown]
# #Q12)  Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56

# %% [markdown]
# 1) 	Find mean, median, variance, standard deviation.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statistics

# %%
marks = [34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]

# %%
statistics.mean(marks)
# Out:
# 41

# %%
statistics.median(marks)
# Out:
# 40.5

# %%
statistics.mode(marks)
# Out:
# 41

# %%
statistics.variance(marks)
# Out:
# 25.529411764705884

# %%
statistics.stdev(marks)
# Out:
# 5.05266382858645

# %% [markdown]
# #	1)	What can we say about the student marks?

# %%
plt.hist(marks)
plt.grid()
plt.show()

# %%
plt.boxplot(marks)
plt.grid()
plt.show()

# %% [markdown]
# we can say that mean of student marks is 41 which is slightly greater than median.
# Most of the students got marks in between 41 and 42.
# Also there are 2 outliers at 49, 56.

# %%
from google.colab import files
cars = files.upload()
# Out:
#      <input type="file" id="files-9fed058d-5234-41d0-bfc6-7025578d4639" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fed058d-5234-41d0-bfc6-7025578d4639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cars=pd.read_csv("Cars.csv")
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
statistics.mean(cars.MPG)
# Out:
# 34.422075728024694

# %%
statistics.stdev(cars.MPG)
# Out:
# 9.131444731795982

# %%
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)>

# %% [markdown]
# #21) Check whether the data follows normal distribution
# Check whether the MPG of Cars follows Normal Distribution

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded= files.upload()

# %%
cars = pd.read_csv("Cars.csv")
cars.head()

# %%
cars['MPG'].mean()

# %%
cars['MPG'].median()

# %%
cars['MPG'].mode()

# %%
cars['MPG'].hist()

# %%
sns.distplot(cars['MPG'])
plt.grid(True)
plt.show()

# %%
cars['MPG'].skew()

# %%
cars['MPG'].kurt()

# %% [markdown]
# #b) Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded= files.upload()
