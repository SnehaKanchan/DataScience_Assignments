# %% [markdown]
# # **K-Means-Clustering- Crime Data**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-3569ec81-db29-42ab-a3b6-7a09f1b756ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3569ec81-db29-42ab-a3b6-7a09f1b756ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Import Dataset
crime = pd.read_csv('crime_data.csv')
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
crime = crime.drop(['Unnamed: 0'],axis=1)
crime
# Out:
#     Murder  Assault  UrbanPop  Rape
# 0     13.2      236        58  21.2
# 1     10.0      263        48  44.5
# 2      8.1      294        80  31.0
# 3      8.8      190        50  19.5
# 4      9.0      276        91  40.6
# 5      7.9      204        78  38.7
# 6      3.3      110        77  11.1
# 7      5.9      238        72  15.8
# 8     15.4      335        80  31.9
# 9     17.4      211        60  25.8
# 10     5.3       46        83  20.2
# 11     2.6      120        54  14.2
# 12    10.4      249        83  24.0
# 13     7.2      113        65  21.0
# 14     2.2       56        57  11.3
# 15     6.0      115        66  18.0
# 16     9.7      109        52  16.3
# 17    15.4      249        66  22.2
# 18     2.1       83        51   7.8
# 19    11.3      300        67  27.8
# 20     4.4      149        85  16.3
# 21    12.1      255        74  35.1
# 22     2.7       72        66  14.9
# 23    16.1      259        44  17.1
# 24     9.0      178        70  28.2
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.7 KB

# %%
# Normalize heterogenous numerical data by using Standard Scaler
crime_norm = StandardScaler().fit_transform(crime)

# %%
# within-cluster sum-of-squares criterion
wcss=[]
for i in range (1,11):
    kmeans = KMeans(n_clusters=i, random_state=2)
    kmeans.fit(crime_norm)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
#plot K values range vs WCSS to ger Elbow graph forchoosing K (no. of clusters)
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # **Build Cluster algorithm using K=4**

# %%
#Cluster algorithm using K=4
cluster4 =KMeans(4,random_state=30).fit(crime_norm)
cluster4
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=30)

# %%
cluster4.labels_
# Out:
# array([0, 3, 3, 0, 3, 3, 1, 1, 3, 0, 1, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 3,
#        2, 0, 3, 2, 2, 3, 2, 1, 3, 3, 0, 2, 1, 1, 1, 1, 1, 0, 2, 0, 3, 1,
#        2, 1, 1, 2, 2, 1], dtype=int32)

# %%
#Assign clusters to the data set
crime4 = crime.copy()
crime4['cluster4id'] = cluster4.labels_
crime4
# Out:
#     Murder  Assault  UrbanPop  Rape  cluster4id
# 0     13.2      236        58  21.2           0
# 1     10.0      263        48  44.5           3
# 2      8.1      294        80  31.0           3
# 3      8.8      190        50  19.5           0
# 4      9.0      276        91  40.6           3
# 5      7.9      204        78  38.7           3
# 6      3.3      110        77  11.1           1
# 7      5.9      238        72  15.8           1
# 8     15.4      335        80  31.9           3
# 9     17.4      211        60  25.8           0
# 10     5.3       46        83  20.2           1
# 11     2.6      120        54  14.2           2
# 12    10.4      249        83  24.0           3
# 13     7.2      113        65  21.0           1
# 14     2.2       56        57  11.3           2
# 15     6.0      115        66  18.0           1
# 16     9.7      109        52  16.3           2
# 17    15.4      249        66  22.2           0
# 18     2.1       83        51   7.8           2
# ...

# %%
# Compute the centroids for K=4 clusters with 11 variables
cluster4.cluster_centers_
# Out:
# array([[ 1.42622412,  0.88321132, -0.82279055,  0.01946669],
#        [-0.49440658, -0.3864845 ,  0.58167593, -0.26431024],
#        [-0.97130281, -1.11783581, -0.93954982, -0.97657842],
#        [ 0.70212683,  1.04999438,  0.72997363,  1.28990383]])

# %%
#Grroup data by Cluster (K=4)
crime4.groupby('cluster4id').agg(['mean']).reset_index()
# Out:
#   cluster4id     Murder     Assault   UrbanPop       Rape
#                    mean        mean       mean       mean
# 0          0  13.937500  243.625000  53.750000  21.412500
# 1          1   5.656250  138.875000  73.875000  18.781250
# 2          2   3.600000   78.538462  52.076923  12.176923
# 3          3  10.815385  257.384615  76.000000  33.192308

# %%
# Plot Clusters
plt.figure(figsize= (10,7))
plt.scatter(crime4['cluster4id'],crime4['UrbanPop'], c=cluster4.labels_)

# %% [markdown]
# # **Build Cluster algorithm using K=5**

# %%
#Cluster algorithm using K=5
cluster5 = KMeans(5,random_state=30).fit(crime_norm)
cluster5
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=30)

# %%
cluster5.labels_
# Out:
# array([1, 2, 2, 0, 2, 2, 4, 0, 2, 1, 4, 3, 2, 0, 3, 0, 0, 1, 3, 2, 4, 2,
#        3, 1, 0, 0, 0, 2, 3, 4, 2, 2, 1, 3, 0, 0, 0, 0, 4, 1, 3, 1, 2, 4,
#        3, 0, 0, 3, 3, 0], dtype=int32)

# %%
#Assign clusters to the data set
crime5 = crime.copy()
crime5['cluster5id']= cluster5.labels_
crime5
# Out:
#     Murder  Assault  UrbanPop  Rape  cluster5id
# 0     13.2      236        58  21.2           1
# 1     10.0      263        48  44.5           2
# 2      8.1      294        80  31.0           2
# 3      8.8      190        50  19.5           0
# 4      9.0      276        91  40.6           2
# 5      7.9      204        78  38.7           2
# 6      3.3      110        77  11.1           4
# 7      5.9      238        72  15.8           0
# 8     15.4      335        80  31.9           2
# 9     17.4      211        60  25.8           1
# 10     5.3       46        83  20.2           4
# 11     2.6      120        54  14.2           3
# 12    10.4      249        83  24.0           2
# 13     7.2      113        65  21.0           0
# 14     2.2       56        57  11.3           3
# 15     6.0      115        66  18.0           0
# 16     9.7      109        52  16.3           0
# 17    15.4      249        66  22.2           1
# 18     2.1       83        51   7.8           3
# ...

# %%
# Compute the centroids for K=5 clusters with 11 variables
cluster5.cluster_centers_
# Out:
# array([[-0.23996529, -0.33082798, -0.0702524 , -0.1343076 ],
#        [ 1.59644066,  0.97606837, -0.78540457,  0.0489325 ],
#        [ 0.73721295,  1.13018079,  0.76486721,  1.33477166],
#        [-1.18467401, -1.2201201 , -1.01470522, -1.11321445],
#        [-0.76257011, -0.53850456,  1.25337729, -0.53550482]])

# %%
#Group data by Clusters (K=5)
crime5.groupby('cluster5id').agg(['mean']).reset_index()
# Out:
#   cluster5id     Murder     Assault   UrbanPop       Rape
#                    mean        mean       mean       mean
# 0          0   6.753333  143.466667  64.533333  19.986667
# 1          1  14.671429  251.285714  54.285714  21.685714
# 2          2  10.966667  264.000000  76.500000  33.608333
# 3          3   2.680000   70.100000  51.000000  10.910000
# 4          4   4.500000  126.333333  83.500000  16.266667

# %%
#Plot Clusters
plt.figure(figsize=(10,7))
plt.scatter(crime5['cluster5id'],crime5['UrbanPop'], c=cluster5.labels_)
